# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler, LabelEncoder
# Train-Test Split
from sklearn.model_selection import train_test_split
# Model Training (Logistic Regression)
from sklearn.linear_model import LogisticRegression
# Model Training (KNN)
from sklearn.neighbors import KNeighborsClassifier
# Model Evaluation
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from mlxtend.plotting import plot_decision_regions

# %%
# pip install mlxtend

# %%
data = pd.read_csv('Cancer_Data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.drop(['id','Unnamed: 32'],axis=1,inplace=True)
data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
Mal = data[data['diagnosis']=='M']
Ben = data[data['diagnosis']=='B']

# %%
Mal
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 563         M        20.92         25.09          143.00     1347.0
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
Ben
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19          B       13.540         14.36           87.46      566.3
# 20          B       13.080         15.71           85.63      520.0
# 21          B        9.504         12.44           60.34      273.9
# 37          B       13.030         18.42           82.61      523.8
# 46          B        8.196         16.84           51.71      201.9
# ..        ...          ...           ...             ...        ...
# 558         B       14.590         22.68           96.39      657.1
# 559         B       11.510         23.93           74.52      403.5
# 560         B       14.050         27.15           91.38      600.4
# 561         B       11.200         29.37           70.67      386.0
# 568         B        7.760         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
plt.scatter(Mal['radius_worst'],Mal['texture_worst'], color = "blue", label = "Malignant", alpha = 0.3)
plt.scatter(Ben['radius_worst'],Ben['texture_worst'], color = "green", label = "Benign", alpha = 0.3)

plt.xlabel("radius_worst")
plt.ylabel("texture_worst")

plt.legend()
plt.show()

# %%
X = data.drop(columns=['diagnosis'])
y = data['diagnosis']  # Target variable

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Encode target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Initialize logistic regression model
log_reg = LogisticRegression(max_iter=1000)  # You can adjust parameters as needed

# %%
# Train the model on the training data
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Predictions on the test set
y_pred = log_reg.predict(X_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9736842105263158

# %%
# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[70  1]
#  [ 2 41]]

# %%
# Generate classification report
class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.97      0.99      0.98        71
#            M       0.98      0.95      0.96        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
def decision_boundary_plot(X, y, X_train, y_train, clf, feature_indexes, title=None):
    if isinstance(X, np.ndarray):
        feature_names = ["Feature " + str(i) for i in feature_indexes]
    else:
        feature_names = X.columns[feature_indexes]
    X_feature_columns = X[:, feature_indexes]
    X_train_feature_columns = X_train[:, feature_indexes]
    clf.fit(X_train_feature_columns, y_train)

    plot_decision_regions(X=X_feature_columns, y=y.values, clf=clf)
    plt.xlabel(feature1_name)
    plt.ylabel(feature2_name)
    plt.title(title)

# %%
feature_indexes = [2, 3]
title1 = 'GaussianNB surface'
# Convert target variable y to integer format
y_train_int = y_train.astype(np.int_)
y_test_int = y_test.astype(np.int_)

decision_boundary_plot(X_test, y_test_int, X_train, y_train_int, log_reg, feature_indexes, title1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 4
#       2 title1 = 'GaussianNB surface'
#       3 # Convert target variable y to integer format
# ----> 4 y_train_int = y_train.astype(np.int_)
#       5 y_test_int = y_test.astype(np.int_)
#       7 decision_boundary_plot(X_test, y_test_int, X_train, y_train_int, log_reg, feature_indexes, title1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
# ...

# %%
# Plot decision boundary
plot_decision_regions(X_train, y_train, clf=log_reg, legend=2)

# Adding axes annotations
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Decision Boundary Plot - Logistic Regression')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 # Plot decision boundary
# ----> 2 plot_decision_regions(X_train[0], y_train, clf=log_reg, legend=2)
#       4 # Adding axes annotations
#       5 plt.xlabel('Feature 1')
#
# File ~\anaconda3\Lib\site-packages\mlxtend\plotting\decision_regions.py:161, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#      50 def plot_decision_regions(
#      51     X,
#      52     y,
#    (...)
#      72     n_jobs=None,
#      73 ):
#      74     """Plot decision regions of a classifier.
#      75
#      76     Please note that this functions assumes that class labels are
#    (...)
#     158
#     159     """
# ...

# %%
from itertools import combinations

# Get all combinations of features
feature_combinations = list(combinations(range(X_train.shape[1]), 2))

# Plot decision boundaries for each pair of features
for i, (feature1, feature2) in enumerate(feature_combinations, start=1):
    plt.figure()
    plot_decision_regions(X_train[:, [feature1, feature2]], y_train, clf=log_reg, legend=2)
    plt.xlabel(f'Feature {feature1}')
    plt.ylabel(f'Feature {feature2}')
    plt.title(f'Decision Boundary Plot - Features {feature1} and {feature2}')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 9
#       7 for i, (feature1, feature2) in enumerate(feature_combinations, start=1):
#       8     plt.figure()
# ----> 9     plot_decision_regions(X_train[:, [feature1, feature2]], y_train, clf=log_reg, legend=2)
#      10     plt.xlabel(f'Feature {feature1}')
#      11     plt.ylabel(f'Feature {feature2}')
#
# File ~\anaconda3\Lib\site-packages\mlxtend\plotting\decision_regions.py:275, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     272             X_predict[:, feature_idx] = filler_feature_values[feature_idx]
#     274 if n_jobs == 1:
# --> 275     Z = clf.predict(X_predict.astype(X.dtype))
# ...

# %%
# Get all combinations of features
feature_combinations = list(combinations(range(X_train.shape[1]), 2))

# Train logistic regression model
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train, y_train)

# Plot decision boundaries for each pair of features
for i, (feature1, feature2) in enumerate(feature_combinations, start=1):
    plt.figure()
    plot_decision_regions(X_train[:, [feature1, feature2]], y_train, clf=log_reg, legend=2)
    plt.xlabel(f'Feature {feature1}')
    plt.ylabel(f'Feature {feature2}')
    plt.title(f'Decision Boundary Plot - Features {feature1} and {feature2}')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 11
#       9 for i, (feature1, feature2) in enumerate(feature_combinations, start=1):
#      10     plt.figure()
# ---> 11     plot_decision_regions(X_train[:, [feature1, feature2]], y_train, clf=log_reg, legend=2)
#      12     plt.xlabel(f'Feature {feature1}')
#      13     plt.ylabel(f'Feature {feature2}')
#
# File ~\anaconda3\Lib\site-packages\mlxtend\plotting\decision_regions.py:275, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     272             X_predict[:, feature_idx] = filler_feature_values[feature_idx]
#     274 if n_jobs == 1:
# --> 275     Z = clf.predict(X_predict.astype(X.dtype))
# ...

# %%
# Get all combinations of features
feature_combinations = list(combinations(range(X_train.shape[1]), 2))

# Plot decision boundaries for each pair of features
for i, (feature1, feature2) in enumerate(feature_combinations, start=1):
    plt.figure()
    plot_decision_regions(X_train[:, [feature1, feature2]], y_train, clf=log_reg, legend=2)
    plt.xlabel(f'Feature {feature1}')
    plt.ylabel(f'Feature {feature2}')
    plt.title(f'Decision Boundary Plot - Features {feature1} and {feature2}')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 7
#       5 for i, (feature1, feature2) in enumerate(feature_combinations, start=1):
#       6     plt.figure()
# ----> 7     plot_decision_regions(X_train[:, [feature1, feature2]], y_train, clf=log_reg, legend=2)
#       8     plt.xlabel(f'Feature {feature1}')
#       9     plt.ylabel(f'Feature {feature2}')
#
# File ~\anaconda3\Lib\site-packages\mlxtend\plotting\decision_regions.py:275, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     272             X_predict[:, feature_idx] = filler_feature_values[feature_idx]
#     274 if n_jobs == 1:
# --> 275     Z = clf.predict(X_predict.astype(X.dtype))
# ...
